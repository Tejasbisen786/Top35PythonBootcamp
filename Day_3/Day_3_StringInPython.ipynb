# %% [markdown]
# ##Strings In Python

# %% [markdown]
# Strings
#
# In Python, a string is a sequence of characters enclosed within either single ('') or double ("") quotation marks. Strings are a fundamental data type used to represent text and are an integral part of most programming tasks, including data manipulation, text processing, and user interaction.

# %%
name = "python"

# %%
name
# Out:
# 'python'

# %% [markdown]
# **Creating Strings:**
#
# 1.   You can create a string by enclosing characters within single or double quotes:
# ```
# single_quoted = 'This is a single-quoted string.'
# double_quoted = "This is a double-quoted string."
# triple_quoted = '''This is a triple-quoted string.'''
#
# ```

# %%
single_quoted = 'This is a single-quoted string.'
double_quoted = "This is a double-quoted string."
triple_quoted = '''This is a triple-quoted string.'''

# %%
print(single_quoted)
print(double_quoted)
print(triple_quoted)
# Out:
# This is a single-quoted string.
# This is a double-quoted string.
# This is a triple-quoted string.

# %% [markdown]
# **String Concatenation:**
# > You can concatenate (combine) strings using the + operator:
#
#
#
# ```
# greeting = "Hello, "
# name = ""
# message = greeting + name
#
# ```

# %%
greeting = "Hello, "
name = "Sumith"
greeting = greeting + name

# %%
name
# Out:
# 'Sumith'

# %%
new_string = "Hello" + " " + "Folks"
new_string
# Out:
# 'Hello Folks'

# %% [markdown]
# **String Indexing and Slicing:**
#
#
# > Python strings are zero-indexed, meaning you can access individual characters using their positions (indices):
#
#
#
# ```
# my_string = "Python"
# first_char = my_string[0]  # 'P'
# second_char = my_string[1]  # 'y'
# ```

# %%
my_string = "Python"
first_char = my_string[0]  # 'P'
second_char = my_string[1]  # 'y'

# %%
first_char
# Out:
# 'P'

# %%
my_string = my_string[0:2]

# %%
my_string = "Python"
my_string = my_string[-7:]

# %%
my_string
# Out:
# 'Python'

# %% [markdown]
# ```
# my_string[-1:-7]
# my_string[-1:]
# my_string[:]
# my_string[-1:]
# my_string[-7:]
# ```

# %%
greeting = "Hello, "
name = "Sumith"
# greeting = greeting + name

# %%
message = greeting[0:5] +" "+ name
message
# Out:
# 'Hello Sumith'

# %% [markdown]
# **Looping Through a String**
# > Since strings are arrays, we can loop through the characters in a string, with a for loop.
#
#
#
# ```
# for x in "Python Programming":
#   print(x)
# ```

# %%
for x in "Python Programming":
  print(x)
# Out:
# P
# y
# t
# h
# o
# n
#
# P
# r
# o
# g
# r
# a
# m
# m
# i
# n
# g

# %%
item = "Python Programming"
for x in range(len(item)):
  print("Value at:", x,"is", item[x])
# Out:
# Value at: 0 is P
# Value at: 1 is y
# Value at: 2 is t
# Value at: 3 is h
# Value at: 4 is o
# Value at: 5 is n
# Value at: 6 is
# Value at: 7 is P
# Value at: 8 is r
# Value at: 9 is o
# Value at: 10 is g
# Value at: 11 is r
# Value at: 12 is a
# Value at: 13 is m
# Value at: 14 is m
# Value at: 15 is i
# Value at: 16 is n
# Value at: 17 is g

# %% [markdown]
# **Check String**
#
# > To check if a certain phrase or character is present in a string, we can use the keyword in.
#
#
# ```
# txt = "Yesterday was Friendship Day"
# print("Day" in txt)
# ```

# %%
txt = "Yesterday was Friendship Day"
print("da" in txt)
# Out:
# True

# %%
attend = "Sumith khedhar harshadha"

# %%
print("Ha" in attend)
# Out:
# False

# %% [markdown]
# **Check if NOT**
#
# > To check if a certain phrase or character is NOT present in a string, we can use the keyword not in.
#
#
#
# ```
# txt = "Yesterday was Friendship Day"
# print("day" not in txt)
# ```

# %%
txt = "Yesterday was Friendship Day"
print("Da" not in txt)
# Out:
# False

# %% [markdown]
# ##**Slicing**
#
# > You can return a range of characters by using the slice syntax.
#
# > Specify the start index and the end index, separated by a colon, to return a part of the string.
#
#
#
# ```
# String = "Python Programming"
# ```

# %% [markdown]
# ##String Functions

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
mystring = "Hi, This is Python Programming session"

# %%
mystring[0:38]
# Out:
# 'Hi, This is Python Programming session'

# %%
len(mystring)
# Out:
# 38

# %%
max(mystring)
# Out:
# 'y'

# %%
min(mystring)
# Out:
# ' '

# %%
print("Hai"*10)
# Out:
# HaiHaiHaiHaiHaiHaiHaiHaiHaiHai

# %% [markdown]
# String Methods:
#
# > Python provides numerous built-in methods to manipulate and work with strings. Some common methods include len(), upper(), lower(), strip(), replace(), split(), and many more.
#
#
#
# ```
# sentence = "This is a sample sentence."
# upper_case = sentence.upper()  # "   THIS IS A SAMPLE SENTENCE.   "
# lower_case = sentence.lower()  # "   this is a sample sentence.   "
# stripped = sentence.strip()    # "This is a sample sentence."
# replaced = sentence.replace("This", "That")
# splitted = sentence.split("a") # returns ['This is', ' sample sentence.']
# ```

# %%
sentence = "This is a sample sentence."
sen="tejas"
upper_case = sentence.upper()  # "   THIS IS A SAMPLE SENTENCE.   "
lower_case = sentence.lower()  # "   this is a sample sentence.   "
stripped = sentence.strip()    # "This is a sample sentence."
replaced = sentence.replace("This", "That")
splitted = sentence.split("a") # returns ['This is', ' sample sentence.']

# %%
upper_case.isupper()
# Out:
# True

# %%
sentence.lower()
# Out:
# 'this is a sample sentence.'

# %%
sentence.replace("i", "a")
# Out:
# 'Thas as a sample sentence.'

# %%
sen.capitalize()
# Out:
# 'Tejas'

# %%
sentence.split("a ")
# Out:
# ['This is ', 'sample sentence.']

# %% [markdown]
# #**String Format**
#
# we can combine strings and numbers by using the format() method!
#
# The format() method takes the passed arguments, formats them, and places them in the string where the placeholders {} are:
#
#
#
# ```
# age = 28
# txt = "My name is Paul, and I am {}"
# print(txt.format(age))
# ```

# %%
quantity = 2
itemno = 567
price = 54.95
myorder = "I want {} dozen of item number {} for {} rupees."
print(myorder.format(quantity, itemno, price))
# Out:
# I want 2 dozen of item number 567 for 54.95 rupees.

# %%
txt = "My name is Paul, and I am "
age = 28
print(txt,age)
# Out:
# My name is Paul, and I am  28

# %% [markdown]
# ##Special Characters
#
#
#
# ```
# Code	Result
# \'	  Single Quote
# \\	  Backslash
# \n	  New Line
# \r	  Carriage Return
# \t	  Tab
# \b	  Backspace
# \f	  Form Feed
# \ooo	Octal value
# \xhh	Hex value
# ```

# %% [markdown]
# My name is 'Paul', and I am  28

# %%
txt = "My name is \\Paul\\, and I am  28"
txt
# Out:
# 'My name is \\Paul\\,\n and I am  28'

# %% [markdown]
# **String Methods Exploration:**
#
#
# ```
# Method	        Description
# capitalize()	  Converts the first character to upper case
# casefold()	    Converts string into lower case
# center()	      Returns a centered string
# count()	       Returns the number of times a specified value occurs in a string
# encode()	      Returns an encoded version of the string
# endswith()	    Returns true if the string ends with the specified value
# expandtabs()	  Sets the tab size of the string
# find()	        Searches the string for a specified value and returns the position of where it was found
# format()	      Formats specified values in a string
# index()	       Searches the string for a specified value and returns the position of where it was found
# isalnum()	     Returns True if all characters in the string are alphanumeric
# isalpha()	     Returns True if all characters in the string are in the alphabet
# isascii()	     Returns True if all characters in the string are ascii characters
# isdecimal()	   Returns True if all characters in the string are decimals
# isdigit()	     Returns True if all characters in the string are digits
# isidentifier()    Returns True if the string is an identifier
# islower()	     Returns True if all characters in the string are lower case
# isnumeric()   	Returns True if all characters in the string are numeric
# isprintable()	 Returns True if all characters in the string are printable
# isspace()     	Returns True if all characters in the string are whitespaces
# istitle()     	Returns True if the string follows the rules of a title
# isupper()	     Returns True if all characters in the string are upper case
# join()	        Joins the elements of an iterable to the end of the string
# ljust()	       Returns a left justified version of the string
# lower()	       Converts a string into lower case
# lstrip()	      Returns a left trim version of the string
# maketrans()	   Returns a translation table to be used in translations
# partition()	   Returns a tuple where the string is parted into three parts
# replace()	     Returns a string where a specified value is replaced with a specified value
# rfind()	       Searches the string for a specified value and returns the last position of where it was found
# rindex()	      Searches the string for a specified value and returns the last position of where it was found
# rjust()	       Returns a right justified version of the string
# rpartition()	  Returns a tuple where the string is parted into three parts
# rsplit()	      Splits the string at the specified separator, and returns a list
# rstrip()	      Returns a right trim version of the string
# split()	       Splits the string at the specified separator, and returns a list
# splitlines()	  Splits the string at line breaks and returns a list
# startswith()	  Returns true if the string starts with the specified value
# strip()	       Returns a trimmed version of the string
# swapcase()	    Swaps cases, lower case becomes upper case and vice versa
# title()	       Converts the first character of each word to upper case
# translate()	   Returns a translated string
# upper()	       Converts a string into upper case
# zfill()	       Fills the string with a specified number of 0 values at the beginning
#
# ```

# %% [markdown]
# String
